# %%
from prednet import PredNet
from datagen import PredNetBatchGenerator
import numpy as np

# %%
bg = PredNetBatchGenerator(video_path="../data/video/20bn-jester-v1",
                 img_size=(64, 64), 
                 batch_size=4,
                 T=40,
                L=10,
                 use_padding=True)

# %%
[x, e, r], [z] = bg.__getitem__(1)

# %%
x.shape
# Out:
# (4, 40, 1, 64, 64, 3)

# %%
e.shape
# Out:
# (4, 40, 10, 64, 64, 6)

# %%
r.shape
# Out:
# (4, 40, 10, 64, 64, 3)

# %%
model = PredNet(T=40, 
                L=10, 
                img_shape=(64,64,3)).build_train()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/embedding_ops.py:132: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# t: 39 l: 9 E: Tensor("concatenate_799/concat:0", shape=(?, 40, 10, 64, 64, 6), dtype=float32)

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# e_input (InputLayer)            (None, 40, 10, 64, 6 0
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 40, 10, 64, 6 0           e_input[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 10, 64, 64, 6 0           lambda_1[0][0]
# __________________________________________________________________________________________________
# lambda_6 (Lambda)               (None, 64, 64, 6)    0           lambda_2[0][0]
# __________________________________________________________________________________________________
# lambda_7 (Lambda)               (None, 1, 64, 64, 6) 0           lambda_6[0][0]
# __________________________________________________________________________________________________
# lambda_9 (Lambda)               (None, 64, 64, 6)    0           lambda_7[0][0]
# __________________________________________________________________________________________________
# lambda_10 (Lambda)              (None, 1, 64, 64, 6) 0           lambda_9[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 2, 64, 64, 6) 0           lambda_7[0][0]
#                                                                  lambda_10[0][0]
# __________________________________________________________________________________________________
# lambda_12 (Lambda)              (None, 64, 64, 6)    0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# lambda_13 (Lambda)              (None, 1, 64, 64, 6) 0           lambda_12[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 3, 64, 64, 6) 0           concatenate_3[0][0]
#                                                                  lambda_13[0][0]
# __________________________________________________________________________________________________
# lambda_15 (Lambda)              (None, 64, 64, 6)    0           concatenate_5[0][0]
# __________________________________________________________________________________________________
# lambda_16 (Lambda)              (None, 1, 64, 64, 6) 0           lambda_15[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 4, 64, 64, 6) 0           concatenate_5[0][0]
#                                                                  lambda_16[0][0]
# __________________________________________________________________________________________________
# lambda_18 (Lambda)              (None, 64, 64, 6)    0           concatenate_7[0][0]
# __________________________________________________________________________________________________
# lambda_19 (Lambda)              (None, 1, 64, 64, 6) 0           lambda_18[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 5, 64, 64, 6) 0           concatenate_7[0][0]
#                                                                  lambda_19[0][0]
# __________________________________________________________________________________________________
# lambda_21 (Lambda)              (None, 64, 64, 6)    0           concatenate_9[0][0]
# __________________________________________________________________________________________________
# lambda_22 (Lambda)              (None, 1, 64, 64, 6) 0           lambda_21[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 6, 64, 64, 6) 0           concatenate_9[0][0]
#                                                                  lambda_22[0][0]
# __________________________________________________________________________________________________
# lambda_24 (Lambda)              (None, 64, 64, 6)    0           concatenate_11[0][0]
# __________________________________________________________________________________________________
# lambda_25 (Lambda)              (None, 1, 64, 64, 6) 0           lambda_24[0][0]
# __________________________________________________________________________________________________
# concatenate_13 (Concatenate)    (None, 7, 64, 64, 6) 0           concatenate_11[0][0]
#                                                                  lambda_25[0][0]
# __________________________________________________________________________________________________
# lambda_27 (Lambda)              (None, 64, 64, 6)    0           concatenate_13[0][0]
# __________________________________________________________________________________________________
# r_input (InputLayer)            (None, 40, 10, 64, 6 0
# __________________________________________________________________________________________________
# lambda_28 (Lambda)              (None, 1, 64, 64, 6) 0           lambda_27[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 10, 64, 64, 3 0           r_input[0][0]
# __________________________________________________________________________________________________
# concatenate_15 (Concatenate)    (None, 8, 64, 64, 6) 0           concatenate_13[0][0]
#                                                                  lambda_28[0][0]
# __________________________________________________________________________________________________
# lambda_32 (Lambda)              (None, 64, 64, 3)    0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_30 (Lambda)              (None, 64, 64, 6)    0           concatenate_15[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 64, 64, 3)    84          lambda_32[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 64, 64, 3)    165         lambda_30[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 64, 64, 3)    0           conv2d_19[0][0]
# __________________________________________________________________________________________________
# subtract_19 (Subtract)          (None, 64, 64, 3)    0           conv2d_18[0][0]
#                                                                  activation_28[0][0]
# __________________________________________________________________________________________________
# subtract_20 (Subtract)          (None, 64, 64, 3)    0           activation_28[0][0]
#                                                                  conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 64, 64, 3)    0           subtract_19[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 64, 64, 3)    0           subtract_20[0][0]
# __________________________________________________________________________________________________
# lambda_31 (Lambda)              (None, 1, 64, 64, 6) 0           lambda_30[0][0]
# __________________________________________________________________________________________________
# concatenate_18 (Concatenate)    (None, 64, 64, 6)    0           activation_29[0][0]
#                                                                  activation_30[0][0]
# __________________________________________________________________________________________________
# concatenate_17 (Concatenate)    (None, 9, 64, 64, 6) 0           concatenate_15[0][0]
#                                                                  lambda_31[0][0]
# __________________________________________________________________________________________________
# lambda_33 (Lambda)              (None, 1, 64, 64, 6) 0           concatenate_18[0][0]
# __________________________________________________________________________________________________
# concatenate_19 (Concatenate)    (None, 10, 64, 64, 6 0           concatenate_17[0][0]
#                                                                  lambda_33[0][0]
# __________________________________________________________________________________________________
# lambda_34 (Lambda)              (None, 1, 10, 64, 64 0           concatenate_19[0][0]
# __________________________________________________________________________________________________
# lambda_35 (Lambda)              (None, 10, 64, 64, 6 0           lambda_34[0][0]
# __________________________________________________________________________________________________
# lambda_39 (Lambda)              (None, 64, 64, 6)    0           lambda_35[0][0]
# __________________________________________________________________________________________________
# lambda_40 (Lambda)              (None, 1, 64, 64, 6) 0           lambda_39[0][0]
# __________________________________________________________________________________________________
# lambda_42 (Lambda)              (None, 64, 64, 6)    0           lambda_40[0][0]
# __________________________________________________________________________________________________
# lambda_43 (Lambda)              (None, 1, 64, 64, 6) 0           lambda_42[0][0]
# __________________________________________________________________________________________________
# concatenate_22 (Concatenate)    (None, 2, 64, 64, 6) 0           lambda_40[0][0]
#                                                                  lambda_43[0][0]
# __________________________________________________________________________________________________
# lambda_45 (Lambda)              (None, 64, 64, 6)    0           concatenate_22[0][0]
# __________________________________________________________________________________________________
# lambda_46 (Lambda)              (None, 1, 64, 64, 6) 0           lambda_45[0][0]
# __________________________________________________________________________________________________
# concatenate_24 (Concatenate)    (None, 3, 64, 64, 6) 0           concatenate_22[0][0]
#                                                                  lambda_46[0][0]
# __________________________________________________________________________________________________
# lambda_48 (Lambda)              (None, 64, 64, 6)    0           concatenate_24[0][0]
# __________________________________________________________________________________________________
# lambda_49 (Lambda)              (None, 1, 64, 64, 6) 0           lambda_48[0][0]
# __________________________________________________________________________________________________
# concatenate_26 (Concatenate)    (None, 4, 64, 64, 6) 0           concatenate_24[0][0]
#                                                                  lambda_49[0][0]
# __________________________________________________________________________________________________
# lambda_51 (Lambda)              (None, 64, 64, 6)    0           concatenate_26[0][0]
# __________________________________________________________________________________________________
# lambda_52 (Lambda)              (None, 1, 64, 64, 6) 0           lambda_51[0][0]
# __________________________________________________________________________________________________
# concatenate_28 (Concatenate)    (None, 5, 64, 64, 6) 0           concatenate_26[0][0]
#                                                                  lambda_52[0][0]
# __________________________________________________________________________________________________
# lambda_54 (Lambda)              (None, 64, 64, 6)    0           concatenate_28[0][0]
# __________________________________________________________________________________________________
# lambda_55 (Lambda)              (None, 1, 64, 64, 6) 0           lambda_54[0][0]
# __________________________________________________________________________________________________
# concatenate_30 (Concatenate)    (None, 6, 64, 64, 6) 0           concatenate_28[0][0]
#                                                                  lambda_55[0][0]
# __________________________________________________________________________________________________
# lambda_57 (Lambda)              (None, 64, 64, 6)    0           concatenate_30[0][0]
# __________________________________________________________________________________________________
# lambda_58 (Lambda)              (None, 1, 64, 64, 6) 0           lambda_57[0][0]
# __________________________________________________________________________________________________
# concatenate_32 (Concatenate)    (None, 7, 64, 64, 6) 0           concatenate_30[0][0]
#                                                                  lambda_58[0][0]
# __________________________________________________________________________________________________
# lambda_60 (Lambda)              (None, 64, 64, 6)    0           concatenate_32[0][0]
# __________________________________________________________________________________________________
# lambda_36 (Lambda)              (None, 10, 64, 64, 6 0           lambda_35[0][0]
# __________________________________________________________________________________________________
# lambda_61 (Lambda)              (None, 1, 64, 64, 6) 0           lambda_60[0][0]
# __________________________________________________________________________________________________
# conv_lst_m2d_1 (ConvLSTM2D)     [(None, 10, 64, 64,  984         lambda_36[0][0]
# __________________________________________________________________________________________________
# concatenate_34 (Concatenate)    (None, 8, 64, 64, 6) 0           concatenate_32[0][0]
#                                                                  lambda_61[0][0]
# __________________________________________________________________________________________________
# lambda_65 (Lambda)              (None, 64, 64, 3)    0           conv_lst_m2d_1[0][0]
# __________________________________________________________________________________________________
# lambda_63 (Lambda)              (None, 64, 64, 6)    0           concatenate_34[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 64, 64, 3)    84          lambda_65[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 64, 64, 3)    165         lambda_63[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 64, 64, 3)    0           conv2d_38[0][0]
# __________________________________________________________________________________________________
# subtract_39 (Subtract)          (None, 64, 64, 3)    0           conv2d_37[0][0]
#                                                                  activation_58[0][0]
# __________________________________________________________________________________________________
# subtract_40 (Subtract)          (None, 64, 64, 3)    0           activation_58[0][0]
#                                                                  conv2d_37[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 64, 64, 3)    0           subtract_39[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 64, 64, 3)    0           subtract_40[0][0]
# __________________________________________________________________________________________________
# lambda_64 (Lambda)              (None, 1, 64, 64, 6) 0           lambda_63[0][0]
# __________________________________________________________________________________________________
# concatenate_37 (Concatenate)    (None, 64, 64, 6)    0           activation_59[0][0]
#                                                                  activation_60[0][0]
# __________________________________________________________________________________________________
# concatenate_36 (Concatenate)    (None, 9, 64, 64, 6) 0           concatenate_34[0][0]
#                                                                  lambda_64[0][0]
# __________________________________________________________________________________________________
# lambda_66 (Lambda)              (None, 1, 64, 64, 6) 0           concatenate_37[0][0]
# __________________________________________________________________________________________________
# concatenate_38 (Concatenate)    (None, 10, 64, 64, 6 0           concatenate_36[0][0]
#                                                                  lambda_66[0][0]
# __________________________________________________________________________________________________
# lambda_67 (Lambda)              (None, 1, 10, 64, 64 0           concatenate_38[0][0]
# __________________________________________________________________________________________________
# concatenate_39 (Concatenate)    (None, 2, 10, 64, 64 0           lambda_34[0][0]
#                                                                  lambda_67[0][0]
# __________________________________________________________________________________________________
# lambda_68 (Lambda)              (None, 10, 64, 64, 6 0           concatenate_39[0][0]
# __________________________________________________________________________________________________
# lambda_72 (Lambda)              (None, 64, 64, 6)    0           lambda_68[0][0]
# __________________________________________________________________________________________________
# lambda_73 (Lambda)              (None, 1, 64, 64, 6) 0           lambda_72[0][0]
# __________________________________________________________________________________________________
# lambda_75 (Lambda)              (None, 64, 64, 6)    0           lambda_73[0][0]
# __________________________________________________________________________________________________
# lambda_76 (Lambda)              (None, 1, 64, 64, 6) 0           lambda_75[0][0]
# __________________________________________________________________________________________________
# concatenate_42 (Concatenate)    (None, 2, 64, 64, 6) 0           lambda_73[0][0]
#                                                                  lambda_76[0][0]
# __________________________________________________________________________________________________
# lambda_78 (Lambda)              (None, 64, 64, 6)    0           concatenate_42[0][0]
# __________________________________________________________________________________________________
# lambda_79 (Lambda)              (None, 1, 64, 64, 6) 0           lambda_78[0][0]
# __________________________________________________________________________________________________
# concatenate_44 (Concatenate)    (None, 3, 64, 64, 6) 0           concatenate_42[0][0]
#                                                                  lambda_79[0][0]
# __________________________________________________________________________________________________
# lambda_81 (Lambda)              (None, 64, 64, 6)    0           concatenate_44[0][0]
# __________________________________________________________________________________________________
# lambda_82 (Lambda)              (None, 1, 64, 64, 6) 0           lambda_81[0][0]
# __________________________________________________________________________________________________
# concatenate_46 (Concatenate)    (None, 4, 64, 64, 6) 0           concatenate_44[0][0]
#                                                                  lambda_82[0][0]
# __________________________________________________________________________________________________
# lambda_84 (Lambda)              (None, 64, 64, 6)    0           concatenate_46[0][0]
# __________________________________________________________________________________________________
# lambda_85 (Lambda)              (None, 1, 64, 64, 6) 0           lambda_84[0][0]
# __________________________________________________________________________________________________
# concatenate_48 (Concatenate)    (None, 5, 64, 64, 6) 0           concatenate_46[0][0]
#                                                                  lambda_85[0][0]
# __________________________________________________________________________________________________
# lambda_87 (Lambda)              (None, 64, 64, 6)    0           concatenate_48[0][0]
# __________________________________________________________________________________________________
# lambda_88 (Lambda)              (None, 1, 64, 64, 6) 0           lambda_87[0][0]
# __________________________________________________________________________________________________
# concatenate_50 (Concatenate)    (None, 6, 64, 64, 6) 0           concatenate_48[0][0]
#                                                                  lambda_88[0][0]
# __________________________________________________________________________________________________
# lambda_90 (Lambda)              (None, 64, 64, 6)    0           concatenate_50[0][0]
# __________________________________________________________________________________________________
# lambda_91 (Lambda)              (None, 1, 64, 64, 6) 0           lambda_90[0][0]
# __________________________________________________________________________________________________
# concatenate_52 (Concatenate)    (None, 7, 64, 64, 6) 0           concatenate_50[0][0]
#                                                                  lambda_91[0][0]
# __________________________________________________________________________________________________
# lambda_93 (Lambda)              (None, 64, 64, 6)    0           concatenate_52[0][0]
# __________________________________________________________________________________________________
# lambda_69 (Lambda)              (None, 10, 64, 64, 6 0           lambda_68[0][0]
# __________________________________________________________________________________________________
# lambda_94 (Lambda)              (None, 1, 64, 64, 6) 0           lambda_93[0][0]
# __________________________________________________________________________________________________
# conv_lst_m2d_2 (ConvLSTM2D)     [(None, 10, 64, 64,  984         lambda_69[0][0]
# __________________________________________________________________________________________________
# concatenate_54 (Concatenate)    (None, 8, 64, 64, 6) 0           concatenate_52[0][0]
#                                                                  lambda_94[0][0]
# __________________________________________________________________________________________________
# lambda_98 (Lambda)              (None, 64, 64, 3)    0           conv_lst_m2d_2[0][0]
# __________________________________________________________________________________________________
# lambda_96 (Lambda)              (None, 64, 64, 6)    0           concatenate_54[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 64, 64, 3)    84          lambda_98[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 64, 64, 3)    165         lambda_96[0][0]
# __________________________________________________________________________________________________
# activation_88 (Activation)      (None, 64, 64, 3)    0           conv2d_57[0][0]
# __________________________________________________________________________________________________
# subtract_59 (Subtract)          (None, 64, 64, 3)    0           conv2d_56[0][0]
#                                                                  activation_88[0][0]
# __________________________________________________________________________________________________
# subtract_60 (Subtract)          (None, 64, 64, 3)    0           activation_88[0][0]
#                                                                  conv2d_56[0][0]
# __________________________________________________________________________________________________
# activation_89 (Activation)      (None, 64, 64, 3)    0           subtract_59[0][0]
# __________________________________________________________________________________________________
# activation_90 (Activation)      (None, 64, 64, 3)    0           subtract_60[0][0]
# __________________________________________________________________________________________________
# lambda_97 (Lambda)              (None, 1, 64, 64, 6) 0           lambda_96[0][0]
# __________________________________________________________________________________________________
# concatenate_57 (Concatenate)    (None, 64, 64, 6)    0           activation_89[0][0]
#                                                                  activation_90[0][0]
# __________________________________________________________________________________________________
# concatenate_56 (Concatenate)    (None, 9, 64, 64, 6) 0           concatenate_54[0][0]
#                                                                  lambda_97[0][0]
# __________________________________________________________________________________________________
# lambda_99 (Lambda)              (None, 1, 64, 64, 6) 0           concatenate_57[0][0]
# __________________________________________________________________________________________________
# concatenate_58 (Concatenate)    (None, 10, 64, 64, 6 0           concatenate_56[0][0]
#                                                                  lambda_99[0][0]
# __________________________________________________________________________________________________
# lambda_100 (Lambda)             (None, 1, 10, 64, 64 0           concatenate_58[0][0]
# __________________________________________________________________________________________________
# concatenate_59 (Concatenate)    (None, 3, 10, 64, 64 0           concatenate_39[0][0]
#                                                                  lambda_100[0][0]
# __________________________________________________________________________________________________
# lambda_101 (Lambda)             (None, 10, 64, 64, 6 0           concatenate_59[0][0]
# __________________________________________________________________________________________________
# lambda_105 (Lambda)             (None, 64, 64, 6)    0           lambda_101[0][0]
# __________________________________________________________________________________________________
# lambda_106 (Lambda)             (None, 1, 64, 64, 6) 0           lambda_105[0][0]
# __________________________________________________________________________________________________
# lambda_108 (Lambda)             (None, 64, 64, 6)    0           lambda_106[0][0]
# __________________________________________________________________________________________________
# lambda_109 (Lambda)             (None, 1, 64, 64, 6) 0           lambda_108[0][0]
# __________________________________________________________________________________________________
# concatenate_62 (Concatenate)    (None, 2, 64, 64, 6) 0           lambda_106[0][0]
#                                                                  lambda_109[0][0]
# __________________________________________________________________________________________________
# lambda_111 (Lambda)             (None, 64, 64, 6)    0           concatenate_62[0][0]
# __________________________________________________________________________________________________
# lambda_112 (Lambda)             (None, 1, 64, 64, 6) 0           lambda_111[0][0]
# __________________________________________________________________________________________________
# concatenate_64 (Concatenate)    (None, 3, 64, 64, 6) 0           concatenate_62[0][0]
#                                                                  lambda_112[0][0]
# __________________________________________________________________________________________________
# lambda_114 (Lambda)             (None, 64, 64, 6)    0           concatenate_64[0][0]
# __________________________________________________________________________________________________
# lambda_115 (Lambda)             (None, 1, 64, 64, 6) 0           lambda_114[0][0]
# __________________________________________________________________________________________________
# concatenate_66 (Concatenate)    (None, 4, 64, 64, 6) 0           concatenate_64[0][0]
#                                                                  lambda_115[0][0]
# __________________________________________________________________________________________________
# lambda_117 (Lambda)             (None, 64, 64, 6)    0           concatenate_66[0][0]
# __________________________________________________________________________________________________
# lambda_118 (Lambda)             (None, 1, 64, 64, 6) 0           lambda_117[0][0]
# __________________________________________________________________________________________________
# concatenate_68 (Concatenate)    (None, 5, 64, 64, 6) 0           concatenate_66[0][0]
#                                                                  lambda_118[0][0]
# __________________________________________________________________________________________________
# lambda_120 (Lambda)             (None, 64, 64, 6)    0           concatenate_68[0][0]
# __________________________________________________________________________________________________
# lambda_121 (Lambda)             (None, 1, 64, 64, 6) 0           lambda_120[0][0]
# __________________________________________________________________________________________________
# concatenate_70 (Concatenate)    (None, 6, 64, 64, 6) 0           concatenate_68[0][0]
#                                                                  lambda_121[0][0]
# __________________________________________________________________________________________________
# lambda_123 (Lambda)             (None, 64, 64, 6)    0           concatenate_70[0][0]
# __________________________________________________________________________________________________
# lambda_124 (Lambda)             (None, 1, 64, 64, 6) 0           lambda_123[0][0]
# __________________________________________________________________________________________________
# concatenate_72 (Concatenate)    (None, 7, 64, 64, 6) 0           concatenate_70[0][0]
#                                                                  lambda_124[0][0]
# __________________________________________________________________________________________________
# lambda_126 (Lambda)             (None, 64, 64, 6)    0           concatenate_72[0][0]
# __________________________________________________________________________________________________
# lambda_102 (Lambda)             (None, 10, 64, 64, 6 0           lambda_101[0][0]
# __________________________________________________________________________________________________
# lambda_127 (Lambda)             (None, 1, 64, 64, 6) 0           lambda_126[0][0]
# __________________________________________________________________________________________________
# conv_lst_m2d_3 (ConvLSTM2D)     [(None, 10, 64, 64,  984         lambda_102[0][0]
# __________________________________________________________________________________________________
# concatenate_74 (Concatenate)    (None, 8, 64, 64, 6) 0           concatenate_72[0][0]
#                                                                  lambda_127[0][0]
# __________________________________________________________________________________________________
# lambda_131 (Lambda)             (None, 64, 64, 3)    0           conv_lst_m2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_129 (Lambda)             (None, 64, 64, 6)    0           concatenate_74[0][0]
# __________________________________________________________________________________________________
# conv2d_76 (Conv2D)              (None, 64, 64, 3)    84          lambda_131[0][0]
# __________________________________________________________________________________________________
# conv2d_75 (Conv2D)              (None, 64, 64, 3)    165         lambda_129[0][0]
# __________________________________________________________________________________________________
# activation_118 (Activation)     (None, 64, 64, 3)    0           conv2d_76[0][0]
# __________________________________________________________________________________________________
# subtract_79 (Subtract)          (None, 64, 64, 3)    0           conv2d_75[0][0]
#                                                                  activation_118[0][0]
# __________________________________________________________________________________________________
# subtract_80 (Subtract)          (None, 64, 64, 3)    0           activation_118[0][0]
#                                                                  conv2d_75[0][0]
# __________________________________________________________________________________________________
# activation_119 (Activation)     (None, 64, 64, 3)    0           subtract_79[0][0]
# __________________________________________________________________________________________________
# activation_120 (Activation)     (None, 64, 64, 3)    0           subtract_80[0][0]
# __________________________________________________________________________________________________
# lambda_130 (Lambda)             (None, 1, 64, 64, 6) 0           lambda_129[0][0]
# __________________________________________________________________________________________________
# concatenate_77 (Concatenate)    (None, 64, 64, 6)    0           activation_119[0][0]
#                                                                  activation_120[0][0]
# __________________________________________________________________________________________________
# concatenate_76 (Concatenate)    (None, 9, 64, 64, 6) 0           concatenate_74[0][0]
#                                                                  lambda_130[0][0]
# __________________________________________________________________________________________________
# lambda_132 (Lambda)             (None, 1, 64, 64, 6) 0           concatenate_77[0][0]
# __________________________________________________________________________________________________
# concatenate_78 (Concatenate)    (None, 10, 64, 64, 6 0           concatenate_76[0][0]
#                                                                  lambda_132[0][0]
# __________________________________________________________________________________________________
# lambda_133 (Lambda)             (None, 1, 10, 64, 64 0           concatenate_78[0][0]
# __________________________________________________________________________________________________
# concatenate_79 (Concatenate)    (None, 4, 10, 64, 64 0           concatenate_59[0][0]
#                                                                  lambda_133[0][0]
# __________________________________________________________________________________________________
# lambda_134 (Lambda)             (None, 10, 64, 64, 6 0           concatenate_79[0][0]
# __________________________________________________________________________________________________
# lambda_138 (Lambda)             (None, 64, 64, 6)    0           lambda_134[0][0]
# __________________________________________________________________________________________________
# lambda_139 (Lambda)             (None, 1, 64, 64, 6) 0           lambda_138[0][0]
# __________________________________________________________________________________________________
# lambda_141 (Lambda)             (None, 64, 64, 6)    0           lambda_139[0][0]
# __________________________________________________________________________________________________
# lambda_142 (Lambda)             (None, 1, 64, 64, 6) 0           lambda_141[0][0]
# __________________________________________________________________________________________________
# concatenate_82 (Concatenate)    (None, 2, 64, 64, 6) 0           lambda_139[0][0]
#                                                                  lambda_142[0][0]
# __________________________________________________________________________________________________
# lambda_144 (Lambda)             (None, 64, 64, 6)    0           concatenate_82[0][0]
# __________________________________________________________________________________________________
# lambda_145 (Lambda)             (None, 1, 64, 64, 6) 0           lambda_144[0][0]
# __________________________________________________________________________________________________
# concatenate_84 (Concatenate)    (None, 3, 64, 64, 6) 0           concatenate_82[0][0]
#                                                                  lambda_145[0][0]
# __________________________________________________________________________________________________
# lambda_147 (Lambda)             (None, 64, 64, 6)    0           concatenate_84[0][0]
# __________________________________________________________________________________________________
# lambda_148 (Lambda)             (None, 1, 64, 64, 6) 0           lambda_147[0][0]
# __________________________________________________________________________________________________
# concatenate_86 (Concatenate)    (None, 4, 64, 64, 6) 0           concatenate_84[0][0]
#                                                                  lambda_148[0][0]
# __________________________________________________________________________________________________
# lambda_150 (Lambda)             (None, 64, 64, 6)    0           concatenate_86[0][0]
# __________________________________________________________________________________________________
# lambda_151 (Lambda)             (None, 1, 64, 64, 6) 0           lambda_150[0][0]
# __________________________________________________________________________________________________
# concatenate_88 (Concatenate)    (None, 5, 64, 64, 6) 0           concatenate_86[0][0]
#                                                                  lambda_151[0][0]
# __________________________________________________________________________________________________
# lambda_153 (Lambda)             (None, 64, 64, 6)    0           concatenate_88[0][0]
# __________________________________________________________________________________________________
# lambda_154 (Lambda)             (None, 1, 64, 64, 6) 0           lambda_153[0][0]
# __________________________________________________________________________________________________
# concatenate_90 (Concatenate)    (None, 6, 64, 64, 6) 0           concatenate_88[0][0]
#                                                                  lambda_154[0][0]
# __________________________________________________________________________________________________
# lambda_156 (Lambda)             (None, 64, 64, 6)    0           concatenate_90[0][0]
# __________________________________________________________________________________________________
# lambda_157 (Lambda)             (None, 1, 64, 64, 6) 0           lambda_156[0][0]
# __________________________________________________________________________________________________
# concatenate_92 (Concatenate)    (None, 7, 64, 64, 6) 0           concatenate_90[0][0]
#                                                                  lambda_157[0][0]
# __________________________________________________________________________________________________
# lambda_159 (Lambda)             (None, 64, 64, 6)    0           concatenate_92[0][0]
# __________________________________________________________________________________________________
# lambda_135 (Lambda)             (None, 10, 64, 64, 6 0           lambda_134[0][0]
# __________________________________________________________________________________________________
# lambda_160 (Lambda)             (None, 1, 64, 64, 6) 0           lambda_159[0][0]
# __________________________________________________________________________________________________
# conv_lst_m2d_4 (ConvLSTM2D)     [(None, 10, 64, 64,  984         lambda_135[0][0]
# __________________________________________________________________________________________________
# concatenate_94 (Concatenate)    (None, 8, 64, 64, 6) 0           concatenate_92[0][0]
#                                                                  lambda_160[0][0]
# __________________________________________________________________________________________________
# lambda_164 (Lambda)             (None, 64, 64, 3)    0           conv_lst_m2d_4[0][0]
# __________________________________________________________________________________________________
# lambda_162 (Lambda)             (None, 64, 64, 6)    0           concatenate_94[0][0]
# __________________________________________________________________________________________________
# conv2d_95 (Conv2D)              (None, 64, 64, 3)    84          lambda_164[0][0]
# __________________________________________________________________________________________________
# conv2d_94 (Conv2D)              (None, 64, 64, 3)    165         lambda_162[0][0]
# __________________________________________________________________________________________________
# activation_148 (Activation)     (None, 64, 64, 3)    0           conv2d_95[0][0]
# __________________________________________________________________________________________________
# subtract_99 (Subtract)          (None, 64, 64, 3)    0           conv2d_94[0][0]
#                                                                  activation_148[0][0]
# __________________________________________________________________________________________________
# subtract_100 (Subtract)         (None, 64, 64, 3)    0           activation_148[0][0]
#                                                                  conv2d_94[0][0]
# __________________________________________________________________________________________________
# activation_149 (Activation)     (None, 64, 64, 3)    0           subtract_99[0][0]
# __________________________________________________________________________________________________
# activation_150 (Activation)     (None, 64, 64, 3)    0           subtract_100[0][0]
# __________________________________________________________________________________________________
# lambda_163 (Lambda)             (None, 1, 64, 64, 6) 0           lambda_162[0][0]
# __________________________________________________________________________________________________
# concatenate_97 (Concatenate)    (None, 64, 64, 6)    0           activation_149[0][0]
#                                                                  activation_150[0][0]
# __________________________________________________________________________________________________
# concatenate_96 (Concatenate)    (None, 9, 64, 64, 6) 0           concatenate_94[0][0]
#                                                                  lambda_163[0][0]
# __________________________________________________________________________________________________
# lambda_165 (Lambda)             (None, 1, 64, 64, 6) 0           concatenate_97[0][0]
# __________________________________________________________________________________________________
# concatenate_98 (Concatenate)    (None, 10, 64, 64, 6 0           concatenate_96[0][0]
#                                                                  lambda_165[0][0]
# __________________________________________________________________________________________________
# ...
# __________________________________________________________________________________________________
# lambda_1276 (Lambda)            (None, 1, 64, 64, 6) 0           lambda_1275[0][0]
# __________________________________________________________________________________________________
# concatenate_770 (Concatenate)   (None, 6, 64, 64, 6) 0           concatenate_768[0][0]
#                                                                  lambda_1276[0][0]
# __________________________________________________________________________________________________
# lambda_1278 (Lambda)            (None, 64, 64, 6)    0           concatenate_770[0][0]
# __________________________________________________________________________________________________
# lambda_1279 (Lambda)            (None, 1, 64, 64, 6) 0           lambda_1278[0][0]
# __________________________________________________________________________________________________
# concatenate_772 (Concatenate)   (None, 7, 64, 64, 6) 0           concatenate_770[0][0]
#                                                                  lambda_1279[0][0]
# __________________________________________________________________________________________________
# lambda_1281 (Lambda)            (None, 64, 64, 6)    0           concatenate_772[0][0]
# __________________________________________________________________________________________________
# lambda_1257 (Lambda)            (None, 10, 64, 64, 6 0           lambda_1256[0][0]
# __________________________________________________________________________________________________
# lambda_1282 (Lambda)            (None, 1, 64, 64, 6) 0           lambda_1281[0][0]
# __________________________________________________________________________________________________
# conv_lst_m2d_38 (ConvLSTM2D)    [(None, 10, 64, 64,  984         lambda_1257[0][0]
# __________________________________________________________________________________________________
# concatenate_774 (Concatenate)   (None, 8, 64, 64, 6) 0           concatenate_772[0][0]
#                                                                  lambda_1282[0][0]
# __________________________________________________________________________________________________
# lambda_1286 (Lambda)            (None, 64, 64, 3)    0           conv_lst_m2d_38[0][0]
# __________________________________________________________________________________________________
# lambda_1284 (Lambda)            (None, 64, 64, 6)    0           concatenate_774[0][0]
# __________________________________________________________________________________________________
# conv2d_741 (Conv2D)             (None, 64, 64, 3)    84          lambda_1286[0][0]
# __________________________________________________________________________________________________
# conv2d_740 (Conv2D)             (None, 64, 64, 3)    165         lambda_1284[0][0]
# __________________________________________________________________________________________________
# activation_1168 (Activation)    (None, 64, 64, 3)    0           conv2d_741[0][0]
# __________________________________________________________________________________________________
# subtract_779 (Subtract)         (None, 64, 64, 3)    0           conv2d_740[0][0]
#                                                                  activation_1168[0][0]
# __________________________________________________________________________________________________
# subtract_780 (Subtract)         (None, 64, 64, 3)    0           activation_1168[0][0]
#                                                                  conv2d_740[0][0]
# __________________________________________________________________________________________________
# activation_1169 (Activation)    (None, 64, 64, 3)    0           subtract_779[0][0]
# __________________________________________________________________________________________________
# activation_1170 (Activation)    (None, 64, 64, 3)    0           subtract_780[0][0]
# __________________________________________________________________________________________________
# lambda_1285 (Lambda)            (None, 1, 64, 64, 6) 0           lambda_1284[0][0]
# __________________________________________________________________________________________________
# concatenate_777 (Concatenate)   (None, 64, 64, 6)    0           activation_1169[0][0]
#                                                                  activation_1170[0][0]
# __________________________________________________________________________________________________
# concatenate_776 (Concatenate)   (None, 9, 64, 64, 6) 0           concatenate_774[0][0]
#                                                                  lambda_1285[0][0]
# __________________________________________________________________________________________________
# lambda_1287 (Lambda)            (None, 1, 64, 64, 6) 0           concatenate_777[0][0]
# __________________________________________________________________________________________________
# concatenate_778 (Concatenate)   (None, 10, 64, 64, 6 0           concatenate_776[0][0]
#                                                                  lambda_1287[0][0]
# __________________________________________________________________________________________________
# lambda_1288 (Lambda)            (None, 1, 10, 64, 64 0           concatenate_778[0][0]
# __________________________________________________________________________________________________
# concatenate_779 (Concatenate)   (None, 39, 10, 64, 6 0           concatenate_759[0][0]
#                                                                  lambda_1288[0][0]
# __________________________________________________________________________________________________
# lambda_1289 (Lambda)            (None, 10, 64, 64, 6 0           concatenate_779[0][0]
# __________________________________________________________________________________________________
# lambda_1293 (Lambda)            (None, 64, 64, 6)    0           lambda_1289[0][0]
# __________________________________________________________________________________________________
# lambda_1294 (Lambda)            (None, 1, 64, 64, 6) 0           lambda_1293[0][0]
# __________________________________________________________________________________________________
# lambda_1296 (Lambda)            (None, 64, 64, 6)    0           lambda_1294[0][0]
# __________________________________________________________________________________________________
# lambda_1297 (Lambda)            (None, 1, 64, 64, 6) 0           lambda_1296[0][0]
# __________________________________________________________________________________________________
# concatenate_782 (Concatenate)   (None, 2, 64, 64, 6) 0           lambda_1294[0][0]
#                                                                  lambda_1297[0][0]
# __________________________________________________________________________________________________
# lambda_1299 (Lambda)            (None, 64, 64, 6)    0           concatenate_782[0][0]
# __________________________________________________________________________________________________
# lambda_1300 (Lambda)            (None, 1, 64, 64, 6) 0           lambda_1299[0][0]
# __________________________________________________________________________________________________
# concatenate_784 (Concatenate)   (None, 3, 64, 64, 6) 0           concatenate_782[0][0]
#                                                                  lambda_1300[0][0]
# __________________________________________________________________________________________________
# lambda_1302 (Lambda)            (None, 64, 64, 6)    0           concatenate_784[0][0]
# __________________________________________________________________________________________________
# lambda_1303 (Lambda)            (None, 1, 64, 64, 6) 0           lambda_1302[0][0]
# __________________________________________________________________________________________________
# concatenate_786 (Concatenate)   (None, 4, 64, 64, 6) 0           concatenate_784[0][0]
#                                                                  lambda_1303[0][0]
# __________________________________________________________________________________________________
# lambda_1305 (Lambda)            (None, 64, 64, 6)    0           concatenate_786[0][0]
# __________________________________________________________________________________________________
# lambda_1306 (Lambda)            (None, 1, 64, 64, 6) 0           lambda_1305[0][0]
# __________________________________________________________________________________________________
# concatenate_788 (Concatenate)   (None, 5, 64, 64, 6) 0           concatenate_786[0][0]
#                                                                  lambda_1306[0][0]
# __________________________________________________________________________________________________
# lambda_1308 (Lambda)            (None, 64, 64, 6)    0           concatenate_788[0][0]
# __________________________________________________________________________________________________
# lambda_1309 (Lambda)            (None, 1, 64, 64, 6) 0           lambda_1308[0][0]
# __________________________________________________________________________________________________
# concatenate_790 (Concatenate)   (None, 6, 64, 64, 6) 0           concatenate_788[0][0]
#                                                                  lambda_1309[0][0]
# __________________________________________________________________________________________________
# lambda_1311 (Lambda)            (None, 64, 64, 6)    0           concatenate_790[0][0]
# __________________________________________________________________________________________________
# lambda_1312 (Lambda)            (None, 1, 64, 64, 6) 0           lambda_1311[0][0]
# __________________________________________________________________________________________________
# concatenate_792 (Concatenate)   (None, 7, 64, 64, 6) 0           concatenate_790[0][0]
#                                                                  lambda_1312[0][0]
# __________________________________________________________________________________________________
# lambda_1314 (Lambda)            (None, 64, 64, 6)    0           concatenate_792[0][0]
# __________________________________________________________________________________________________
# lambda_1290 (Lambda)            (None, 10, 64, 64, 6 0           lambda_1289[0][0]
# __________________________________________________________________________________________________
# lambda_1315 (Lambda)            (None, 1, 64, 64, 6) 0           lambda_1314[0][0]
# __________________________________________________________________________________________________
# conv_lst_m2d_39 (ConvLSTM2D)    [(None, 10, 64, 64,  984         lambda_1290[0][0]
# __________________________________________________________________________________________________
# concatenate_794 (Concatenate)   (None, 8, 64, 64, 6) 0           concatenate_792[0][0]
#                                                                  lambda_1315[0][0]
# __________________________________________________________________________________________________
# lambda_1319 (Lambda)            (None, 64, 64, 3)    0           conv_lst_m2d_39[0][0]
# __________________________________________________________________________________________________
# lambda_1317 (Lambda)            (None, 64, 64, 6)    0           concatenate_794[0][0]
# __________________________________________________________________________________________________
# conv2d_760 (Conv2D)             (None, 64, 64, 3)    84          lambda_1319[0][0]
# __________________________________________________________________________________________________
# conv2d_759 (Conv2D)             (None, 64, 64, 3)    165         lambda_1317[0][0]
# __________________________________________________________________________________________________
# activation_1198 (Activation)    (None, 64, 64, 3)    0           conv2d_760[0][0]
# __________________________________________________________________________________________________
# subtract_799 (Subtract)         (None, 64, 64, 3)    0           conv2d_759[0][0]
#                                                                  activation_1198[0][0]
# __________________________________________________________________________________________________
# subtract_800 (Subtract)         (None, 64, 64, 3)    0           activation_1198[0][0]
#                                                                  conv2d_759[0][0]
# __________________________________________________________________________________________________
# activation_1199 (Activation)    (None, 64, 64, 3)    0           subtract_799[0][0]
# __________________________________________________________________________________________________
# activation_1200 (Activation)    (None, 64, 64, 3)    0           subtract_800[0][0]
# __________________________________________________________________________________________________
# lambda_1318 (Lambda)            (None, 1, 64, 64, 6) 0           lambda_1317[0][0]
# __________________________________________________________________________________________________
# concatenate_797 (Concatenate)   (None, 64, 64, 6)    0           activation_1199[0][0]
#                                                                  activation_1200[0][0]
# __________________________________________________________________________________________________
# concatenate_796 (Concatenate)   (None, 9, 64, 64, 6) 0           concatenate_794[0][0]
#                                                                  lambda_1318[0][0]
# __________________________________________________________________________________________________
# lambda_1320 (Lambda)            (None, 1, 64, 64, 6) 0           concatenate_797[0][0]
# __________________________________________________________________________________________________
# concatenate_798 (Concatenate)   (None, 10, 64, 64, 6 0           concatenate_796[0][0]
#                                                                  lambda_1320[0][0]
# __________________________________________________________________________________________________
# lambda_1321 (Lambda)            (None, 1, 10, 64, 64 0           concatenate_798[0][0]
# __________________________________________________________________________________________________
# concatenate_799 (Concatenate)   (None, 40, 10, 64, 6 0           concatenate_779[0][0]
#                                                                  lambda_1321[0][0]
# ==================================================================================================
# Total params: 48,336
# Trainable params: 48,336
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
import numpy as np
import keras
import keras.backend as K

class PredNet( ):
    def __init__(self, T=40, L=10, img_shape=(64,64,3)):
        self.T = T
        self.L = L
        self.img_h = img_shape[0]
        self.img_w = img_shape[1]
        self.img_c = img_shape[2]
        
        self.x_shape = (self.T, 1,      self.img_h, self.img_w, self.img_c    )
        self.e_shape = (self.T, self.L, self.img_h, self.img_w, self.img_c * 2)
        self.r_shape = (self.T, self.L, self.img_h, self.img_w, self.img_c    )
        
    def build_train(self):
        # Input Lauer
        # T: 50, L: 10, h:64, w:64, c:3
        X_input = keras.layers.Input(shape=self.x_shape, dtype='float32', name='x_input')
        E_input = keras.layers.Input(shape=self.e_shape, dtype='float32', name='e_input')
        R_input = keras.layers.Input(shape=self.r_shape, dtype='float32', name='r_input')

        for t in range(self.T):
            """ === E unit === """
            if t == 0:
                E = keras.layers.Lambda(lambda x: x)(E_input)

            def E_to_Et(E):
                # E_t: (None, L, h, w, 2c)
                E_t = K.permute_dimensions(E, [1, 0, 2, 3, 4, 5])
                E_t = K.gather(E_t, [t])
                E_t = K.permute_dimensions(E_t, [1, 0, 2, 3, 4, 5])
                E_t = K.squeeze(E_t, axis=1)
                return E_t
            E_t = keras.layers.Lambda(E_to_Et)(E)

            """ === R unit === """
            if t == 0:
                def R_to_Rt(R_input):
                    R_t = K.permute_dimensions(R_input, [1, 0, 2, 3, 4, 5])
                    R_t = K.gather(R_t, [t])
                    R_t = K.permute_dimensions(R_t, [1, 0, 2, 3, 4, 5])
                    R_t = K.squeeze(R_t, axis=1)
                    return R_t
                R_t = keras.layers.Lambda(R_to_Rt)(R_input)
            else:
                # R_t: (None, L, h, w, 3)
                E_t_rev = keras.layers.Lambda(lambda x: K.reverse(x, axes=1))(E_t)
                R_t, state_h_t, state_c_t = keras.layers.ConvLSTM2D(3, (3, 3), 
                                                                    padding='same', 
                                                                    activation='tanh', 
                                                                    return_sequences=True, 
                                                                    return_state=True)(E_t_rev)
            

            for l in range(self.L):  
                """ === R_tl === """
                def Rt_to_Rtl(R_t):
                    R_tl = K.permute_dimensions(R_t, [1, 0, 2, 3, 4])
                    R_tl = K.gather(R_tl, [l])
                    R_tl = K.permute_dimensions(R_tl, [1, 0, 2, 3, 4])
                    R_tl = K.squeeze(R_tl, axis=1)
                    return R_tl
                # R_tl: (None, h, w, 3)
                R_tl = keras.layers.Lambda(Rt_to_Rtl)(R_t)                
                
                """ === Ahat_tl === """
                # Ahat_tl: (None, h, w, 3)
                Ahat_tl = keras.layers.Conv2D(3, (3, 3), padding='same')(R_tl)
                Ahat_tl = keras.layers.Activation('relu')(Ahat_tl)

                if l == 0:                    
                    def X_to_Atl(x_input):
                        # (None, T, 1, h, w, c) --> (?, h, w, c)
                        A_tl = K.squeeze(x_input, axis=2) # (None, T, 64, 64, 3)
                        A_tl = K.permute_dimensions(A_tl, [1, 0, 2, 3, 4]) # (T, None, 64, 64, 3)
                        A_tl = K.gather(A_tl, [t]) # (1, None, 64, 64, 3)
                        A_tl = K.squeeze(A_tl, axis=0) # (None, 64, 64, 3)
                        return A_tl

                    # A_tl: (None, h, w, 3)
                    A_tl = keras.layers.Lambda(X_to_Atl)(X_input)

                # E_tl: (None, h, w, c)
                err0_tl = keras.layers.Subtract()([A_tl, Ahat_tl])
                err0_tl = keras.layers.Activation('relu')(err0_tl)
                err1_tl = keras.layers.Subtract()([Ahat_tl, A_tl])
                err1_tl = keras.layers.Activation('relu')(err1_tl)
                E_tl    = keras.layers.Concatenate(axis=-1)([err0_tl, err1_tl])

                # A_tl: (None, h, w, 3)
                if l < self.L-1:
                    def Et_to_Etl(E_t):
                        E_tl = K.permute_dimensions(E_t, [1, 0, 2, 3, 4])
                        E_tl = K.gather(E_tl, [l])
                        E_tl = K.permute_dimensions(E_tl, [1, 0, 2, 3, 4])
                        E_tl = K.squeeze(E_tl, axis=1)
                        return E_tl

                    # E_tl: (None, h, w, c)
                    E_tl = keras.layers.Lambda(Et_to_Etl)(E_t)
                    # A_tl
                    A_tl = keras.layers.Conv2D(3, (3, 3), padding='same')(E_tl)

                if l == 0:
                    # E_l: (None, 1, h, w, c)
                    E_t = keras.layers.Lambda(lambda x: K.expand_dims(x, axis=1))(E_tl)
                else:
                    # E_tl_: (None, 1, h, w, c)
                    E_tl_ = keras.layers.Lambda(lambda x: K.expand_dims(x, axis=1))(E_tl)
                    # E_l: (None, T, h, w, c)
                    E_t = keras.layers.Concatenate(axis=1)([E_t, E_tl_])
            if t == 0:
                # E: (None, 1, T, h, w, c)
                E = keras.layers.Lambda(lambda x : K.expand_dims(x, axis=1))(E_t)
            else:
                # E_l_: (None, 1, T, h, w, c)
                E_t_ = keras.layers.Lambda(lambda x : K.expand_dims(x, axis=1))(E_t)
                # E: (None, L, T, h, w, c)
                E = keras.layers.Concatenate(axis=1)([E, E_t_])
        print("t:", t, "l:", l, "E:", E)

        # print(E) # 50, 10, 64, 64, 6
        model_train = keras.models.Model(inputs=[X_input, E_input, R_input], outputs=[E])
        return model_train
