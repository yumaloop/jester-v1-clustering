# %%
import cv2
import numpy  as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
im = cv2.imread("./data/latent/10179/lat.jpg")

# %%
im
# Out:
# array([[[ 74,  21, 118],
#         [ 60,  16,  85],
#         [ 95,  72,  87],
#         ...,
#         [109,  95,  67],
#         [135, 119,  72],
#         [124, 107,  50]],
#
#        [[ 92,  49, 146],
#         [ 69,  35, 105],
#         [137, 121, 138],
#         ...,
#         [134, 123,  95],
#         [137, 124,  78],
#         [133, 121,  63]],
#
#        [[144, 119, 217],
#         [ 36,  20,  91],
#         [121, 121, 137],
#         ...,
#         [132, 131, 103],
#         [123, 118,  73],
#         [131, 127,  69]],
#
#        ...,
#
#        [[141, 177, 225],
#         [  3,  28,  68],
#         [116, 120, 145],
#         ...,
#         [112, 131, 116],
#         [128, 138, 115],
#         [119, 124,  97]],
#
#        [[139, 189, 212],
#         [ 10,  38,  68],
#         [ 69,  56,  94],
#         ...,
#         [ 83, 143, 119],
#         [ 98, 132, 108],
#         [106, 128, 104]],
#
#        [[ 96, 154, 166],
#         [ 13,  45,  68],
#         [ 60,  37,  81],
# ...

# %%
plt.imshow(im[:,:,0])

# %%
plt.imshow(im[:,:,1])

# %%
plt.imshow(im[:,:,2])

# %%
test_image = cv2.imread("./data/latent/10179/lat.jpg", 0) #グレースケール画像として読み込む.
plt.imshow(test_image)
plt.show()
