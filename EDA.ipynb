# %%
import os
import numpy as np
from PIL import Image

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# !ls -la data
# Out:
# 合計 2933300
# drwxrwxr-x    3 uchiumi uchiumi       4096  9月 24 21:23 .
# drwxrwxr-x    4 uchiumi uchiumi       4096 10月  9 14:22 ..
# -rw-rw-r--    1 uchiumi uchiumi 1000000000  9月 24 20:57 00.tar.gz
# -rw-r--r--    1 uchiumi uchiumi 1000000000  9月 24 21:23 01
# -rw-rw-r--    1 uchiumi uchiumi 1000000000  9月 24 21:22 01.tar.gz
# drwxrwxr-x 6505 uchiumi uchiumi     135168  6月 11  2017 20bn-jester-v1
# -rwx------    1 uchiumi uchiumi        383  9月 24 18:51 download.sh
# -rw-r--r--    1 uchiumi uchiumi        528  9月 24 19:20 labels.csv
# -rw-rw-r--    1 uchiumi uchiumi        379  9月 24 19:07 memo.txt
# -rw-r--r--    1 uchiumi uchiumi      92133  9月 24 19:20 test.csv
# -rw-rw-r--    1 uchiumi uchiumi         96  9月 24 19:14 train
# -rw-r--r--    1 uchiumi uchiumi    3042748  9月 24 19:20 train.csv
# -rw-r--r--    1 uchiumi uchiumi     379289  9月 24 19:20 validation.csv

# %%
# !ls -la data/20bn-jester-v1 | grep 1000
# Out:
# drwxrwxr-x    2 uchiumi uchiumi   4096  6月 10  2017 100005
# drwxrwxr-x    2 uchiumi uchiumi   4096  6月 10  2017 100023
# drwxrwxr-x    2 uchiumi uchiumi   4096  6月 10  2017 100050
# drwxrwxr-x    2 uchiumi uchiumi   4096  6月 11  2017 110002

# %%
# !file data/20bn-jester-v1/100005
# Out:
# data/20bn-jester-v1/100005: directory

# %%
# !ls data/20bn-jester-v1/100005
# Out:
# 00001.jpg  00007.jpg  00013.jpg  00019.jpg  00025.jpg  00031.jpg
# 00002.jpg  00008.jpg  00014.jpg  00020.jpg  00026.jpg  00032.jpg
# 00003.jpg  00009.jpg  00015.jpg  00021.jpg  00027.jpg  00033.jpg
# 00004.jpg  00010.jpg  00016.jpg  00022.jpg  00028.jpg  00034.jpg
# 00005.jpg  00011.jpg  00017.jpg  00023.jpg  00029.jpg  00035.jpg
# 00006.jpg  00012.jpg  00018.jpg  00024.jpg  00030.jpg  00036.jpg

# %%
# 画像の読み込み
img = Image.open('data/20bn-jester-v1/100005/00001.jpg')

#画像の幅と高さを取得
width, height = img.size

# 画像を表示
plt.imshow(img)
print("width :", width)
print("height :", height)
# Out:
# width : 176
# height : 100

# %%
# 画像の読み込み
img = Image.open('data/20bn-jester-v1/100023/00010.jpg')

#画像の幅と高さを取得
width, height = img.size

# 画像を表示
plt.imshow(img)
print("width :", width)
print("height :", height)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-31f60aad1926> in <module>
#       1 # 画像の読み込み
# ----> 2 img = Image.open('data/20bn-jester-v1/100023/00010.jpg')
#       3
#       4 #画像の幅と高さを取得
#       5 width, height = img.size
#
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py in open(fp, mode)
#    2768
#    2769     if filename:
# -> 2770         fp = builtins.open(filename, "rb")
#    2771         exclusive_fp = True
#    2772
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/20bn-jester-v1/100023/00010.jpg'
